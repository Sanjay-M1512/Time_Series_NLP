# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# %%
file_path = r"C:\Users\HP\OneDrive\Desktop\NLP\Data\ML471_S1_Datafile_Practice.csv"

df = pd.read_csv(file_path)

# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Set Date as index
df.set_index('Date', inplace=True)

# Select Close price
close_series = df['Close']

# %%
adf_original = adfuller(close_series)

print("ADF Test on Original Close Price")
print(f"ADF Statistic : {adf_original[0]}")
print(f"P-value       : {adf_original[1]}")
print("-" * 40)
# Out:
# ADF Test on Original Close Price
# ADF Statistic : -0.9169719313810458
# P-value       : 0.7823319492318603
# ----------------------------------------

# %%
diff_close = close_series.diff().dropna()

# %%
adf_diff = adfuller(diff_close)

print("ADF Test on Differenced Close Price")
print(f"ADF Statistic : {adf_diff[0]}")
print(f"P-value       : {adf_diff[1]}")
print("-" * 40)
# Out:
# ADF Test on Differenced Close Price
# ADF Statistic : -40.08896872157196
# P-value       : 0.0
# ----------------------------------------

# %%
plt.figure(figsize=(18, 9))
plt.plot(diff_close, label="Differenced Close Price")
plt.title("Differenced Close Price")
plt.xlabel("Date")
plt.ylabel("Price Change")
plt.legend()
plt.grid(alpha=0.3)
plt.show()
