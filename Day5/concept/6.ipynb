# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='3'
import sys,spacy 
nlp=spacy.load('en_core_web_sm')
import warnings as w
w.filterwarnings('ignore')
with open(os.path.join(sys.path[0],input()),encoding='utf-8') as f:
    c=f.read()

print("Enter text file name:")
print("Original Text Sample:")
print(c[:300])

s1="All is well that ends well ."
d=nlp(s1)
t=[i for i in d if not i.is_space]
print("=== POS Tagging for Sentence 1 ===")
print("Word POS Tag")
print('-'*34)
for i in t:
    print(i.text,i.pos_,i.tag_)
    
s1="Apple is looking at buying a U.K. startup for $ 1 billion dollars ."
d=nlp(s1)
t=[i for i in d if not i.is_space]
print("=== POS Tagging for Sentence 2 ===")
print("Word POS Tag")
print('-'*34)
for i in t:
    print(i.text,i.pos_,i.tag_)
    
s1="Time flies like an arrow ."
d=nlp(s1)
t=[i for i in d if not i.is_space]
print("=== POS Tagging for Sentence 3 ===")
print("Word POS Tag")
print('-'*34)
for i in t:
    print(i.text,i.pos_,i.tag_)
    
s1="The monkey ate the banana before I could stop him ."
d=nlp(s1)
t=[i for i in d if not i.is_space]
print("=== POS Tagging for Sentence 4 ===")
print("Word POS Tag")
print('-'*34)
for i in t:
    print(i.text,i.pos_,i.tag_)
    
d=nlp(c)
t=[i for i in d if not i.is_space]
print("=== POS Tagging for Sentence 5 ===")
print("Word POS Tag")
print('-'*34)
for i in t[:562]:
    print(i.text,i.pos_,i.tag_)
